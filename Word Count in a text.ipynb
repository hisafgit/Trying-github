# %%
text_file = open('/home/jason/Downloads/98-0.txt', 'rb')

# %%
binary_text = text_file.read()

# %%
stringo = binary_text.decode('utf-8')

# %%
print(stringo[5000:5300])
# Out:
# d down in the rain to do honour to a dirty procession of monks
# which passed within his view, at a distance of some fifty or sixty
# yards. It is likely enough that, rooted in the woods of France and
# Norway, there were growing trees, when that sufferer was put to death,
# already marked by the Woodma

# %%
stringo[:100]
# Out:
# '\ufeffThe Project Gutenberg EBook of A Tale of Two Cities, by Charles Dickens\r\n\r\nThis eBook is for the us'

# %%
stringo = stringo.lower()

# %%
stringo[:100]
# Out:
# '\ufeffthe project gutenberg ebook of a tale of two cities, by charles dickens\r\n\r\nthis ebook is for the us'

# %%
stringo = stringo.replace(".","")
stringo = stringo.replace(",","")
stringo = stringo.replace(":","")
stringo = stringo.replace(";","")
stringo = stringo.replace("'","")
stringo = stringo.replace("\"","")
stringo = stringo.replace("”","")
stringo = stringo.replace("“","")
stringo = stringo.replace("?","")
stringo = stringo.replace("!","")
stringo = stringo.replace("`","")
stringo = stringo.replace("´","")

# %%
print(stringo[:100])
# Out:
# ﻿the project gutenberg ebook of a tale of two cities by charles dickens
#
# this ebook is for the use

# %%
words_list = stringo.split()

# %%
word_dict = {}
for word in words_list:
    if word in word_dict:
        word_dict[word] += 1
    else:
        word_dict[word] = 1

# %%
word_dict
# Out:
# {'\ufeffthe': 1,
#  'project': 87,
#  'gutenberg': 29,
#  'ebook': 10,
#  'of': 4132,
#  'a': 2976,
#  'tale': 7,
#  'two': 215,
#  'cities': 7,
#  'by': 577,
#  'charles': 97,
#  'dickens': 4,
#  'this': 591,
#  'is': 830,
#  'for': 966,
#  'the': 8177,
#  'use': 28,
#  'anyone': 5,
#  'anywhere': 6,
#  'at': 1042,
#  'no': 548,
#  'cost': 6,
#  'and': 4984,
#  'with': 1350,
#  'almost': 46,
#  'restrictions': 2,
#  'whatsoever': 3,
#  'you': 1430,
#  'may': 141,
#  'copy': 12,
#  'it': 2008,
#  'give': 47,
#  'away': 133,
#  'or': 431,
#  're-use': 2,
#  'under': 145,
#  'terms': 26,
#  'license': 16,
#  'included': 5,
#  'online': 4,
#  'wwwgutenbergorg': 2,
#  'title': 3,
#  'story': 23,
#  'french': 45,
#  'revolution': 9,
#  'author': 1,
#  'release': 6,
#  'date': 9,
#  'january': 1,
#  '1994': 1,
#  '[ebook': 1,
#  '#98]': 1,
#  'posting': 1,
#  'november': 6,
#  '28': 1,
#  '2009': 1,
#  'last': 134,
#  'updated': 2,
#  'september': 2,
#  '25': 1,
#  '2016': 1,
# ...

# %%
word_double_list = []

# %%
type(word_double_tuple)
# Out:
# tuple

# %%
for pair in word_dict.items():
    word_double_list.append(pair)

# %%
word_double_list
# Out:
# [('\ufeffthe', 1),
#  ('project', 87),
#  ('gutenberg', 29),
#  ('ebook', 10),
#  ('of', 4132),
#  ('a', 2976),
#  ('tale', 7),
#  ('two', 215),
#  ('cities', 7),
#  ('by', 577),
#  ('charles', 97),
#  ('dickens', 4),
#  ('this', 591),
#  ('is', 830),
#  ('for', 966),
#  ('the', 8177),
#  ('use', 28),
#  ('anyone', 5),
#  ('anywhere', 6),
#  ('at', 1042),
#  ('no', 548),
#  ('cost', 6),
#  ('and', 4984),
#  ('with', 1350),
#  ('almost', 46),
#  ('restrictions', 2),
#  ('whatsoever', 3),
#  ('you', 1430),
#  ('may', 141),
#  ('copy', 12),
#  ('it', 2008),
#  ('give', 47),
#  ('away', 133),
#  ('or', 431),
#  ('re-use', 2),
#  ('under', 145),
#  ('terms', 26),
#  ('license', 16),
#  ('included', 5),
#  ('online', 4),
#  ('wwwgutenbergorg', 2),
#  ('title', 3),
#  ('story', 23),
#  ('french', 45),
#  ('revolution', 9),
#  ('author', 1),
#  ('release', 6),
#  ('date', 9),
#  ('january', 1),
#  ('1994', 1),
#  ('[ebook', 1),
#  ('#98]', 1),
#  ('posting', 1),
#  ('november', 6),
# ...

# %%
word_double_list.sort(key=funk, reverse=True)

# %%
word_double_list
# Out:
# [('the', 8177),
#  ('and', 4984),
#  ('of', 4132),
#  ('to', 3541),
#  ('a', 2976),
#  ('in', 2630),
#  ('it', 2008),
#  ('his', 2000),
#  ('that', 1897),
#  ('i', 1881),
#  ('he', 1824),
#  ('was', 1757),
#  ('you', 1430),
#  ('with', 1350),
#  ('had', 1296),
#  ('as', 1136),
#  ('at', 1042),
#  ('her', 1035),
#  ('for', 966),
#  ('him', 961),
#  ('on', 930),
#  ('not', 854),
#  ('is', 830),
#  ('be', 777),
#  ('have', 741),
#  ('said', 657),
#  ('were', 655),
#  ('but', 652),
#  ('my', 648),
#  ('mr', 616),
#  ('this', 591),
#  ('so', 581),
#  ('by', 577),
#  ('all', 570),
#  ('there', 562),
#  ('they', 560),
#  ('no', 548),
#  ('from', 529),
#  ('me', 517),
#  ('if', 462),
#  ('she', 452),
#  ('out', 445),
#  ('one', 435),
#  ('been', 435),
#  ('when', 433),
#  ('or', 431),
#  ('which', 398),
#  ('them', 387),
#  ('who', 372),
#  ('what', 370),
#  ('an', 348),
#  ('would', 340),
#  ('your', 338),
#  ('lorry', 335),
#  ('are', 333),
#  ('into', 319),
#  ('their', 317),
# ...

# %%
def funk(x):
    return x[1]
